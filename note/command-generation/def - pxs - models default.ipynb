# %% [markdown]
# # CLI Config Generator

# %%
from aaai20.io import (
    build_filesystem,
    default_prefix_exp_fn_suffix,
    filename_config,
    filename_cli_commands,
    filename_script,
    filename_logs,
)

from aaai20.cmd_gen import (
    all_fnames_in_dir,
    generate_config_and_log_fname,
    generate_df_commands,
    extract_idx_from_fnames,
    default_start_idx,
    prepare_fs,
)


import json
import os
import pandas as pd
import datetime

# %% [markdown]
# # Functions

# %%
def generate_predict_config(
    dataset="nltcs",
    model_keyword="default",
    exp_keyword="test-exp",
    script="run_mercs",
    exp_idx=0,
    **predict_config
):

    default_predict_config = dict(inferce_algorithm="EPIS_sampling")

    predict_config = {**default_predict_config, **predict_config}

    config = dict(
        dataset=dataset,
        model_keyword=model_keyword,
        exp_keyword=exp_keyword,
        exp_idx=exp_idx,
        predict_config=predict_config,
        script=script,
    )

    return config

def generate_fit_config(
    dataset="nltcs",
    model_keyword="default",
    exp_keyword="test-exp",
    script="run_mercs",
    exp_idx=0,
    **fit_config
):

    default_fit_config = dict()

    fit_config = {**default_fit_config, **fit_config}

    config = dict(
        dataset=dataset,
        model_keyword=model_keyword,
        exp_keyword=exp_keyword,
        exp_idx=exp_idx,
        fit_config=fit_config,
        script=script,
    )

    return config

# %% [markdown]
# # FIT PXS
#
# Build the default PxS models.

# %%
fs = build_filesystem()

starai_ds = set(os.listdir(fs['datasets-starai']))
starai_ds

# %%
# Fixed parameters
exp_keyword = 'fit-pxs'
script="fit_pxs"
fs = build_filesystem()
model_keyword="default",
prepare_fs(exp_keyword, script, fs)

timeout = datetime.timedelta(hours=2).seconds
start_idx = default_start_idx(fs, script=script)

# Grid definition
phase_space = starai_ds

# Inits
df_commands = pd.DataFrame()
fn_cfg = []
fn_log = []
fn_script = filename_script(script, kind='fit')

for p_idx, p in enumerate(phase_space):
    
    # Init
    exp_idx = start_idx + p_idx
    
    # Generate config
    fit_config = dict()

    config = generate_fit_config(
        dataset=p,
        script=script,
        model_keyword=model_keyword,
        exp_keyword=exp_keyword,
        exp_idx=exp_idx,
        **fit_config
    )
    
    # Save config
    single_fn_cfg, single_fn_log = generate_config_and_log_fname(config, kind='fit')
    with open(single_fn_cfg, 'w') as f:
        json.dump(config, f, indent=4)
        
    fn_cfg.append(single_fn_cfg)
    fn_log.append(single_fn_log)

    
df_commands = generate_df_commands(fn_script, fn_cfg, fn_log, timeout)

fn_commands = filename_cli_commands(exp_keyword)
df_commands.to_csv(fn_commands, index=False)
# Out:
# Nothing found, so index is 0

# %%
fn_commands
# Out:
# '/cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/cli-config/demofitpxs.csv'

# %%
df_commands
# Out:
#                                          script_fname  \
# 0   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 1   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 2   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 3   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 4   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 5   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 6   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 7   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 8   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 9   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 10  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 11  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 12  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 13  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 14  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 15  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 16  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 17  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 18  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 19  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
# 20  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/cli/...
#
#                                          config_fname  \
# 0   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 1   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 2   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 3   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 4   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 5   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 6   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 7   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 8   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 9   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 10  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 11  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 12  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 13  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 14  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 15  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 16  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 17  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 18  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 19  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
# 20  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...
#
#                                             log_fname  timeout
# 0   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 1   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 2   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 3   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 4   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 5   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 6   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 7   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 8   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 9   /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 10  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 11  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 12  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 13  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 14  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 15  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 16  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 17  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 18  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 19  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
# 20  /cw/dtaijupiter/NoCsBack/dtai/elia/aaai20/out/...     7200
